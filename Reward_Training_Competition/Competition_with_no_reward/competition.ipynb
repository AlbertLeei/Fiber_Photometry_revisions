# %% [markdown]
# ## Bout Aligned individual trace plots.

# %%
import os
import sys

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.append(PROJECT_ROOT)

print(PROJECT_ROOT)

from experiment_class import Experiment
from bouts_extension import *
from Reward_Training_Competition.Reward_Competition.rc_extension import Reward_Competition

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# c:\Users\yezon\Padilla-Coreano_Lab\UMAP\Fiber_Photometry_revisions

# %%
# NAc
# experiment_path = r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\NAc"
# csv_base_path = r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\NAc"
# brain_region = '#15616F'

# NAc: #15616F
# mPFC: #FFAF00

# mPFC
# experiment_path = r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\mPFC"
# csv_base_path = r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\mPFC"
# brain_region = '#FFAF00'

# test experiment path
# experiment_path = r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\test_rig_data"
# csv_base_path = r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\test_csv"

# all data
experiment_path = r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data"
# csv_base_path = r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data"

# All data minus 5 most tangled:
csv_base_path = r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5"
# Tangled:
# csv_base_path = r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Tangled"

manual_scoring_csv = r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\manual_scoring_combined.xlsx"
pre_window = 5
post_time = 5

# %%
experiment = Reward_Competition(experiment_folder_path=experiment_path, behavior_folder_path=csv_base_path)

experiment.rtc_processing()
# experiment.read_and_merge_manual_scoring(manual_scoring_csv)
# experiment.remove_tangles()
# Out:
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n1-240611-091131\Notes.txt
# read from t=0s to t=2042.14s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n1-240612-113256\Notes.txt
# read from t=0s to t=2055.01s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n1-240614-073020\Notes.txt
# read from t=0s to t=2054.68s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n2-240611-074031\Notes.txt
# read from t=0s to t=2045.31s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n2-240612-072325\Notes.txt
# read from t=0s to t=2041.48s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n2-240613-113505\Notes.txt
# read from t=0s to t=2047.15s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n3-240611-115257\Notes.txt
# read from t=0s to t=2041.61s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n3-240613-085222\Notes.txt
# read from t=0s to t=2043.19s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n3-240614-090514\Notes.txt
# read from t=0s to t=2043.19s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n3-240617-095059\Notes.txt
# read from t=0s to t=2041.48s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n4-240612-085323\Notes.txt
# read from t=0s to t=2041.21s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n4-240613-072239\Notes.txt
# read from t=0s to t=2046.89s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n4-240614-130653\Notes.txt
# read from t=0s to t=2042.41s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n5-240912-080246\Notes.txt
# read from t=0s to t=2051.77s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n5-240913-094304\Notes.txt
# read from t=0s to t=2044.77s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n5-240915-060250\Notes.txt
# read from t=0s to t=2044.96s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n5-240915-095000\Notes.txt
# read from t=0s to t=2070.66s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n6-240912-062009\Notes.txt
# read from t=0s to t=2073.36s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n6-240913-062437\Notes.txt
# read from t=0s to t=2044.96s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n6-240914-065650\Notes.txt
# read from t=0s to t=2047.26s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n6-240914-095611\Notes.txt
# read from t=0s to t=2053.26s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n7-240912-095235\Notes.txt
# read from t=0s to t=1955.86s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n7-240913-080108\Notes.txt
# read from t=0s to t=2044.86s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n7-240914-082547\Notes.txt
# read from t=0s to t=2075.17s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\n7-240915-073140\Notes.txt
# read from t=0s to t=2046.16s
# read from t=0s to t=2055.26s
# read from t=0s to t=2055.26s
# read from t=0s to t=2061.76s
# read from t=0s to t=2061.76s
# read from t=0s to t=2052.17s
# read from t=0s to t=2052.17s
# read from t=0s to t=2387.77s
# read from t=0s to t=2387.77s
# read from t=0s to t=2047.56s
# read from t=0s to t=2047.56s
# read from t=0s to t=2049.47s
# read from t=0s to t=2049.47s
# read from t=0s to t=2059.26s
# read from t=0s to t=2059.26s
# read from t=0s to t=2065.26s
# read from t=0s to t=2065.26s
# read from t=0s to t=2431.87s
# read from t=0s to t=2431.87s
# read from t=0s to t=2072.35s
# read from t=0s to t=2072.35s
# read from t=0s to t=2044.46s
# read from t=0s to t=2044.46s
# read from t=0s to t=2045.26s
# read from t=0s to t=2045.26s
# read from t=0s to t=2046.06s
# read from t=0s to t=2046.06s
# read from t=0s to t=2065.37s
# read from t=0s to t=2065.37s
# read from t=0s to t=2044.26s
# read from t=0s to t=2044.26s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p1-240611-082555\Notes.txt
# read from t=0s to t=2049.07s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p1-240612-104753\Notes.txt
# read from t=0s to t=2046.43s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p1-240614-064528\Notes.txt
# read from t=0s to t=2058.51s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p2-240611-065329\Notes.txt
# read from t=0s to t=2041.61s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p2-240612-063828\Notes.txt
# read from t=0s to t=2041.68s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p2-240613-104938\Notes.txt
# read from t=0s to t=2042.47s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p3-240611-110619\Notes.txt
# read from t=0s to t=2041.61s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p3-240613-080730\Notes.txt
# read from t=0s to t=2041.81s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p3-240614-081850\Notes.txt
# read from t=0s to t=2116.13s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p4-240612-080749\Notes.txt
# read from t=0s to t=2041.54s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p4-240613-063737\Notes.txt
# read from t=0s to t=2041.28s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p4-240614-121422\Notes.txt
# read from t=0s to t=2041.42s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p5-240912-071257\Notes.txt
# read from t=0s to t=2045.16s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p5-240913-085922\Notes.txt
# read from t=0s to t=2044.47s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p5-240915-064653\Notes.txt
# read from t=0s to t=2050.16s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p6-240912-052842\Notes.txt
# read from t=0s to t=2045.86s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p6-240913-054041\Notes.txt
# read from t=0s to t=2047.46s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p6-240914-091051\Notes.txt
# read from t=0s to t=2044.66s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p7-240912-090250\Notes.txt
# read from t=0s to t=2041.86s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p7-240914-074210\Notes.txt
# read from t=0s to t=2044.26s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p8-240913-070924\Notes.txt
# read from t=0s to t=2059.66s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p8-240914-061235\Notes.txt
# read from t=0s to t=2046.86s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p8-240915-051905\Notes.txt
# read from t=0s to t=2044.66s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\Rig Data\All_data\p8-240915-081607\Notes.txt
# read from t=0s to t=2084.46s
# read from t=0s to t=2042.75s
# read from t=0s to t=2042.75s
# read from t=0s to t=2057.57s
# read from t=0s to t=2057.57s
# read from t=0s to t=2231.17s
# read from t=0s to t=2231.17s
# read from t=0s to t=2052.17s
# read from t=0s to t=2052.17s
# read from t=0s to t=2184.07s
# read from t=0s to t=2184.07s
# read from t=0s to t=2078.66s
# read from t=0s to t=2078.66s
# read from t=0s to t=2054.86s
# read from t=0s to t=2054.86s
# read from t=0s to t=2065.37s
# read from t=0s to t=2065.37s
# read from t=0s to t=2047.26s
# read from t=0s to t=2047.26s
# Processing trial n1-240611-091131...
# Processing trial n1-240612-113256...
# Processing trial n1-240614-073020...
# Processing trial n2-240611-074031...
# Processing trial n2-240612-072325...
# Processing trial n2-240613-113505...
# Processing trial n3-240611-115257...
# Processing trial n3-240613-085222...
# Processing trial n3-240614-090514...
# Processing trial n3-240617-095059...
# Processing trial n4-240612-085323...
# Processing trial n4-240613-072239...
# Processing trial n4-240614-130653...
# Processing trial n5-240912-080246...
# Processing trial n5-240913-094304...
# Processing trial n5-240915-060250...
# Processing trial n5-240915-095000...
# Processing trial n6-240912-062009...
# Processing trial n6-240913-062437...
# Processing trial n6-240914-065650...
# Processing trial n6-240914-095611...
# Processing trial n7-240912-095235...
# Processing trial n7-240913-080108...
# Processing trial n7-240914-082547...
# Processing trial n7-240915-073140...
# Processing trial nn1-250203-085508...
# Processing trial nn3-250203-085508...
# Processing trial nn1-250205-090150...
# Processing trial pp1-250205-090150...
# Processing trial nn2-250204-085225...
# Processing trial nn1-250204-085225...
# Processing trial nn2-250205-113735...
# Processing trial nn4-250205-113735...
# Processing trial nn2-250206-053033...
# Processing trial pp2-250206-053033...
# Processing trial nn3-250204-122327...
# Processing trial pp3-250204-122327...
# Processing trial nn4-250206-081929...
# Processing trial nn3-250206-081929...
# Processing trial nn4-250203-121223...
# Processing trial pp4-250203-121223...
# Processing trial nn5-250205-104235...
# Processing trial nn8-250205-104235...
# Processing trial nn5-250203-080636...
# Processing trial pp5-250203-080636...
# Processing trial nn6-250203-112333...
# Processing trial nn7-250203-112333...
# Processing trial nn6-250206-073116...
# Processing trial nn7-250206-073116...
# Processing trial nn7-250205-131504...
# Processing trial pp7-250205-131504...
# Processing trial nn8-250204-113128...
# Processing trial nn5-250204-113128...
# Processing trial nn8-250206-102501...
# Processing trial pp8-250206-102501...
# Processing trial p1-240611-082555...
# Processing trial p1-240612-104753...
# Processing trial p1-240614-064528...
# Processing trial p2-240611-065329...
# Processing trial p2-240612-063828...
# Processing trial p2-240613-104938...
# Processing trial p3-240611-110619...
# Processing trial p3-240613-080730...
# Processing trial p3-240614-081850...
# Processing trial p4-240612-080749...
# Processing trial p4-240613-063737...
# Processing trial p4-240614-121422...
# Processing trial p5-240912-071257...
# Processing trial p5-240913-085922...
# Processing trial p5-240915-064653...
# Processing trial p6-240912-052842...
# Processing trial p6-240913-054041...
# Processing trial p6-240914-091051...
# Processing trial p7-240912-090250...
# Processing trial p7-240914-074210...
# Processing trial p8-240913-070924...
# Processing trial p8-240914-061235...
# Processing trial p8-240915-051905...
# Processing trial p8-240915-081607...
# Processing trial pp1-250203-094756...
# Processing trial pp3-250203-094756...
# Processing trial pp2-250204-095252...
# Processing trial pp1-250204-095252...
# Processing trial pp2-250205-122507...
# Processing trial pp4-250205-122507...
# Processing trial pp4-250206-093423...
# Processing trial pp3-250206-093423...
# Processing trial pp5-250205-095320...
# Processing trial pp8-250205-095320...
# Processing trial pp6-250204-075106...
# Processing trial nn6-250204-075106...
# Processing trial pp6-250203-103606...
# Processing trial pp7-250203-103606...
# Processing trial pp6-250206-062728...
# Processing trial pp7-250206-062728...
# Processing trial pp8-250204-104135...
# Processing trial pp5-250204-104135...

# %%
# trial=experiment.da_df
# vars(trial)

# %% [markdown]
# # Decide to investigate behaviors during cue times or not

# %%
# Step 1: Extract and filter Behaviors
bout_definitions = [
    {'prefix': 'subject_behavior', 'behavior': 'Competition Bout', 'subject': 'Subject'},
    {'prefix': 'agent_behavior', 'behavior': 'Competition Bout', 'subject': 'Social Agent'}
]
# Filters for all behaviors not during cue times
experiment.group_extract_manual_annotations2(bout_definitions,first_only=False, pre_window=pre_window, cue=False)

# Filters for behaviors at/during cue times
# experiment.group_extract_manual_annotations2(bout_definitions,first_only=False, pre_window=pre_window, cue=True)
# Out:
# Warning: No CSV found for n1-240611-091131. Skipping.
# Warning: No CSV found for n1-240612-113256. Skipping.
# Warning: No CSV found for n1-240614-073020. Skipping.
# Warning: No CSV found for n2-240611-074031. Skipping.
# Warning: No CSV found for n2-240612-072325. Skipping.
# Warning: No CSV found for n2-240613-113505. Skipping.
# Warning: No CSV found for n3-240611-115257. Skipping.
# Warning: No CSV found for n3-240613-085222. Skipping.
# Warning: No CSV found for n3-240614-090514. Skipping.
# Warning: No CSV found for n3-240617-095059. Skipping.
# Warning: No CSV found for n4-240612-085323. Skipping.
# Warning: No CSV found for n4-240613-072239. Skipping.
# Warning: No CSV found for n4-240614-130653. Skipping.
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\n5-240912-080246.csv
# After combining # bouts: 8
# 8
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\n5-240913-094304.csv
# After combining # bouts: 35
# 35
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\n5-240915-060250.csv
# After combining # bouts: 57
# 53
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\n5-240915-095000.csv
# After combining # bouts: 8
# 8
# Warning: No CSV found for n6-240912-062009. Skipping.
# Warning: No CSV found for n6-240913-062437. Skipping.
# Warning: No CSV found for n6-240914-065650. Skipping.
# Warning: No CSV found for n6-240914-095611. Skipping.
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\n7-240912-095235.csv
# After combining # bouts: 19
# 19
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\n7-240913-080108.csv
# After combining # bouts: 8
# 8
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\n7-240914-082547.csv
# After combining # bouts: 20
# 20
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\n7-240915-073140.csv
# After combining # bouts: 1
# 1
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\nn1-250203-085508.csv
# After combining # bouts: 59
# 59
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\nn3-250203-085508.csv
# c:\Users\yezon\Padilla-Coreano_Lab\UMAP\Fiber_Photometry_revisions\trial_class.py:1352: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.behaviors = pd.concat(self.bouts.values(), ignore_index=True)
# c:\Users\yezon\Padilla-Coreano_Lab\UMAP\Fiber_Photometry_revisions\trial_class.py:1352: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.behaviors = pd.concat(self.bouts.values(), ignore_index=True)
# c:\Users\yezon\Padilla-Coreano_Lab\UMAP\Fiber_Photometry_revisions\trial_class.py:1352: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.behaviors = pd.concat(self.bouts.values(), ignore_index=True)
# c:\Users\yezon\Padilla-Coreano_Lab\UMAP\Fiber_Photometry_revisions\trial_class.py:1352: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.behaviors = pd.concat(self.bouts.values(), ignore_index=True)
# After combining # bouts: 90
# 87
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\nn1-250205-090150.csv
# After combining # bouts: 32
# 32
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\pp1-250205-090150.csv
# After combining # bouts: 19
# 19
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\nn2-250204-085225.csv
# After combining # bouts: 80
# 73
# Warning: No CSV found for nn1-250204-085225. Skipping.
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\nn2-250205-113735.csv
# After combining # bouts: 3
# 3
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\nn4-250205-113735.csv
# After combining # bouts: 8
# 8
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\nn2-250206-053033.csv
# After combining # bouts: 37
# 37
# Warning: No CSV found for pp2-250206-053033. Skipping.
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\nn3-250204-122327.csv
# After combining # bouts: 19
# 19
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\pp3-250204-122327.csv
# After combining # bouts: 8
# 8
# Warning: No CSV found for nn4-250206-081929. Skipping.
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\nn3-250206-081929.csv
# After combining # bouts: 5
# 5
# Warning: No CSV found for nn4-250203-121223. Skipping.
# Warning: No CSV found for pp4-250203-121223. Skipping.
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\nn5-250205-104235.csv
# After combining # bouts: 59
# 59
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\nn8-250205-104235.csv
# After combining # bouts: 8
# 8
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\nn5-250203-080636.csv
# After combining # bouts: 37
# 37
# Warning: No CSV found for pp5-250203-080636. Skipping.
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\nn6-250203-112333.csv
# After combining # bouts: 51
# 46
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\nn7-250203-112333.csv
# After combining # bouts: 65
# 60
# Warning: No CSV found for nn6-250206-073116. Skipping.
# Warning: No CSV found for nn7-250206-073116. Skipping.
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\nn7-250205-131504.csv
# After combining # bouts: 36
# 36
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\pp7-250205-131504.csv
# After combining # bouts: 16
# 16
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\nn8-250204-113128.csv
# After combining # bouts: 89
# 88
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\nn5-250204-113128.csv
# After combining # bouts: 13
# 13
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\nn8-250206-102501.csv
# After combining # bouts: 42
# 42
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\pp8-250206-102501.csv
# After combining # bouts: 25
# 24
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\p1-240611-082555.csv
# After combining # bouts: 24
# 24
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\p1-240612-104753.csv
# After combining # bouts: 25
# 25
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\p1-240614-064528.csv
# After combining # bouts: 31
# 31
# Warning: No CSV found for p2-240611-065329. Skipping.
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\p2-240612-063828.csv
# After combining # bouts: 1
# 1
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\p2-240613-104938.csv
# After combining # bouts: 35
# 35
# Warning: No CSV found for p3-240611-110619. Skipping.
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\p3-240613-080730.csv
# After combining # bouts: 6
# 6
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\p3-240614-081850.csv
# After combining # bouts: 3
# 3
# Warning: No CSV found for p4-240612-080749. Skipping.
# Warning: No CSV found for p4-240613-063737. Skipping.
# Warning: No CSV found for p4-240614-121422. Skipping.
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\p5-240912-071257.csv
# After combining # bouts: 46
# 46
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\p5-240913-085922.csv
# After combining # bouts: 16
# 16
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\p5-240915-064653.csv
# After combining # bouts: 29
# 26
# Warning: No CSV found for p6-240912-052842. Skipping.
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\p6-240913-054041.csv
# After combining # bouts: 8
# 8
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\p6-240914-091051.csv
# After combining # bouts: 14
# 13
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\p7-240912-090250.csv
# After combining # bouts: 10
# 10
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\p7-240914-074210.csv
# After combining # bouts: 13
# 13
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\p8-240913-070924.csv
# After combining # bouts: 3
# 3
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\p8-240914-061235.csv
# After combining # bouts: 11
# 11
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\p8-240915-051905.csv
# After combining # bouts: 5
# 5
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\p8-240915-081607.csv
# After combining # bouts: 10
# 10
# Warning: No CSV found for pp1-250203-094756. Skipping.
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\pp3-250203-094756.csv
# After combining # bouts: 70
# 70
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\pp2-250204-095252.csv
# After combining # bouts: 33
# 32
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\pp1-250204-095252.csv
# After combining # bouts: 6
# 6
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\pp2-250205-122507.csv
# After combining # bouts: 8
# 8
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\pp4-250205-122507.csv
# After combining # bouts: 10
# 10
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\pp4-250206-093423.csv
# After combining # bouts: 7
# 6
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\pp3-250206-093423.csv
# After combining # bouts: 21
# 20
# Warning: No CSV found for pp5-250205-095320. Skipping.
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\pp8-250205-095320.csv
# After combining # bouts: 5
# 5
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\pp6-250204-075106.csv
# After combining # bouts: 13
# 13
# Warning: No CSV found for nn6-250204-075106. Skipping.
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\pp6-250203-103606.csv
# After combining # bouts: 88
# 86
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\pp7-250203-103606.csv
# After combining # bouts: 75
# 70
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\pp6-250206-062728.csv
# After combining # bouts: 11
# 11
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\pp7-250206-062728.csv
# After combining # bouts: 27
# 27
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\pp8-250204-104135.csv
# After combining # bouts: 28
# 27
# C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Full_data\minus_5\pp5-250204-104135.csv
# After combining # bouts: 21
# 21
# c:\Users\yezon\Padilla-Coreano_Lab\UMAP\Fiber_Photometry_revisions\trial_class.py:1352: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.behaviors = pd.concat(self.bouts.values(), ignore_index=True)
# c:\Users\yezon\Padilla-Coreano_Lab\UMAP\Fiber_Photometry_revisions\trial_class.py:1352: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.behaviors = pd.concat(self.bouts.values(), ignore_index=True)

# %% [markdown]
# ## Compute DA (standard or EI)

# %%
# Step 2: Compute DA traces
# Event Induced DA
experiment.compute_all_event_induced_DA(pre_time=pre_window, post_time=post_time)

# Standard Z-scored DA
# experiment.compute_all_da_metrics(max_bout_duration=30, mode='standard', post_time=5)
# Out:
# Computing event-induced DA for trial n1-240611-091131 ...
# Trial n1: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial n1-240612-113256 ...
# Trial n1: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial n1-240614-073020 ...
# Trial n1: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial n2-240611-074031 ...
# Trial n2: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial n2-240612-072325 ...
# Trial n2: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial n2-240613-113505 ...
# Trial n2: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial n3-240611-115257 ...
# Trial n3: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial n3-240613-085222 ...
# Trial n3: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial n3-240614-090514 ...
# Trial n3: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial n3-240617-095059 ...
# Trial n3: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial n4-240612-085323 ...
# Trial n4: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial n4-240613-072239 ...
# Trial n4: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial n4-240614-130653 ...
# Trial n4: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial n5-240912-080246 ...
# Computing event-induced DA for trial n5-240913-094304 ...
# Computing event-induced DA for trial n5-240915-060250 ...
# Computing event-induced DA for trial n5-240915-095000 ...
# Computing event-induced DA for trial n6-240912-062009 ...
# Trial n6: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial n6-240913-062437 ...
# Trial n6: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial n6-240914-065650 ...
# Trial n6: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial n6-240914-095611 ...
# Trial n6: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial n7-240912-095235 ...
# Computing event-induced DA for trial n7-240913-080108 ...
# Computing event-induced DA for trial n7-240914-082547 ...
# Computing event-induced DA for trial n7-240915-073140 ...
# Computing event-induced DA for trial nn1-250203-085508 ...
# Computing event-induced DA for trial nn3-250203-085508 ...
# Computing event-induced DA for trial nn1-250205-090150 ...
# Computing event-induced DA for trial pp1-250205-090150 ...
# Computing event-induced DA for trial nn2-250204-085225 ...
# Computing event-induced DA for trial nn1-250204-085225 ...
# Trial nn2_nn1: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial nn2-250205-113735 ...
# Computing event-induced DA for trial nn4-250205-113735 ...
# Computing event-induced DA for trial nn2-250206-053033 ...
# Computing event-induced DA for trial pp2-250206-053033 ...
# Trial nn2_pp2: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial nn3-250204-122327 ...
# Computing event-induced DA for trial pp3-250204-122327 ...
# Computing event-induced DA for trial nn4-250206-081929 ...
# Trial nn4_nn3: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial nn3-250206-081929 ...
# Computing event-induced DA for trial nn4-250203-121223 ...
# Trial nn4_pp4: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial pp4-250203-121223 ...
# Trial nn4_pp4: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial nn5-250205-104235 ...
# Computing event-induced DA for trial nn8-250205-104235 ...
# Computing event-induced DA for trial nn5-250203-080636 ...
# Computing event-induced DA for trial pp5-250203-080636 ...
# Trial nn5_pp5: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial nn6-250203-112333 ...
# Computing event-induced DA for trial nn7-250203-112333 ...
# Computing event-induced DA for trial nn6-250206-073116 ...
# Trial nn6_nn7: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial nn7-250206-073116 ...
# Trial nn6_nn7: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial nn7-250205-131504 ...
# Computing event-induced DA for trial pp7-250205-131504 ...
# Computing event-induced DA for trial nn8-250204-113128 ...
# Computing event-induced DA for trial nn5-250204-113128 ...
# Computing event-induced DA for trial nn8-250206-102501 ...
# Computing event-induced DA for trial pp8-250206-102501 ...
# Computing event-induced DA for trial p1-240611-082555 ...
# Computing event-induced DA for trial p1-240612-104753 ...
# Computing event-induced DA for trial p1-240614-064528 ...
# Computing event-induced DA for trial p2-240611-065329 ...
# Trial p2: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial p2-240612-063828 ...
# Computing event-induced DA for trial p2-240613-104938 ...
# Computing event-induced DA for trial p3-240611-110619 ...
# Trial p3: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial p3-240613-080730 ...
# Computing event-induced DA for trial p3-240614-081850 ...
# Computing event-induced DA for trial p4-240612-080749 ...
# Trial p4: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial p4-240613-063737 ...
# Trial p4: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial p4-240614-121422 ...
# Trial p4: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial p5-240912-071257 ...
# Computing event-induced DA for trial p5-240913-085922 ...
# Computing event-induced DA for trial p5-240915-064653 ...
# Computing event-induced DA for trial p6-240912-052842 ...
# Trial p6: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial p6-240913-054041 ...
# Computing event-induced DA for trial p6-240914-091051 ...
# Computing event-induced DA for trial p7-240912-090250 ...
# Computing event-induced DA for trial p7-240914-074210 ...
# Computing event-induced DA for trial p8-240913-070924 ...
# Computing event-induced DA for trial p8-240914-061235 ...
# Computing event-induced DA for trial p8-240915-051905 ...
# Computing event-induced DA for trial p8-240915-081607 ...
# Computing event-induced DA for trial pp1-250203-094756 ...
# Trial pp1_pp3: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial pp3-250203-094756 ...
# Computing event-induced DA for trial pp2-250204-095252 ...
# Computing event-induced DA for trial pp1-250204-095252 ...
# Computing event-induced DA for trial pp2-250205-122507 ...
# Computing event-induced DA for trial pp4-250205-122507 ...
# Computing event-induced DA for trial pp4-250206-093423 ...
# Computing event-induced DA for trial pp3-250206-093423 ...
# Computing event-induced DA for trial pp5-250205-095320 ...
# Trial pp5_pp8: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial pp8-250205-095320 ...
# Computing event-induced DA for trial pp6-250204-075106 ...
# Computing event-induced DA for trial nn6-250204-075106 ...
# Trial pp6_nn6: No behavior events available for event-induced DA computation.
# Computing event-induced DA for trial pp6-250203-103606 ...
# Computing event-induced DA for trial pp7-250203-103606 ...
# Computing event-induced DA for trial pp6-250206-062728 ...
# Computing event-induced DA for trial pp7-250206-062728 ...
# Computing event-induced DA for trial pp8-250204-104135 ...
# Computing event-induced DA for trial pp5-250204-104135 ...

# %% [markdown]
# ### Non-Reward Build

# %%
# Step 3: build dataframe
subj_traces_df = experiment.build_subject_traces_df("Competition Bout")

# Step 4: compute subject means
subj_traces = experiment.compute_subject_mean_traces_non_reward(
    df=subj_traces_df,
    event_type="Competition Bout"
)

# %% [markdown]
# ### Reward Build (only looks at tone related bouts)

# %%
# creates an event bank that stores all events and DA (Aligned to bout initiation)
# experiment.build_subject_traces_df_reward(cue_window=10)

# %%
# trial_name = list(experiment.event_traces.keys())[0]

# initiator = list(experiment.event_traces[trial_name].keys())[0]

# bout = experiment.event_traces[trial_name][initiator][0]

# print(bout)

# %% [markdown]
# ## Plots for initator competitions

# %%
# experiment.plot_event_bank_by_trial(initiator="Subject",
#                                save_path=r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Plots",
#                                )

# %%
# experiment.plot_event_bank_by_trial(initiator="Social Agent",
#                                save_path=r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Plots",
#                                )

# %% [markdown]
# ### Plots for Non-reward induced competition

# %%
experiment.plot_group_mean_traces_non_reward(
    subj_traces=subj_traces,
    event_type="Competition Bout",
    brain_region="mPFC",
    initiator=None,
    title="mPFC all initiated competition bouts",
    pre_window=-5,
    post_time=post_time,
    save_path=r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Plots\non-reward\mPFC_all_initiated"
)

experiment.plot_group_mean_traces_non_reward(
    subj_traces=subj_traces,
    event_type="Competition Bout",
    brain_region="NAc",
    initiator=None,
    title="NAc all initiated competition bouts",
    pre_window=-5,
    post_time=post_time,
    save_path=r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Plots\non-reward\NAc_all_initiated"
)

# %%
experiment.plot_group_mean_traces_non_reward(
    subj_traces=subj_traces,
    event_type="Competition Bout",
    brain_region="mPFC",
    initiator="Subject",
    title="mPFC subject initiated competition bouts",
    pre_window=-5,
    post_time=post_time,
    save_path=r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Plots\non-reward\mPFC_subject_initiated"
)

experiment.plot_group_mean_traces_non_reward(
    subj_traces=subj_traces,
    event_type="Competition Bout",
    brain_region="mPFC",
    initiator="Social Agent",
    title="mPFC competitor initiated competition bouts",
    pre_window=-5,
    post_time=post_time,
    save_path=r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Plots\non-reward\mPFC_agent_initiated"
)

# %%
experiment.plot_group_mean_traces_non_reward(
    subj_traces=subj_traces,
    event_type="Competition Bout",
    brain_region="NAc",
    initiator="Subject",
    title="NAc subject initiated competition bouts",
    pre_window=-5,
    post_time=post_time,
    save_path=r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Plots\non-reward\NAc_subject_initiated"
)

experiment.plot_group_mean_traces_non_reward(
    subj_traces=subj_traces,
    event_type="Competition Bout",
    brain_region="NAc",
    initiator="Social Agent",
    title="NAc competitor initiated competition bouts",
    pre_window=-5,
    post_time=post_time,
    save_path=r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Comp\Data\BORIS-nonreward\Plots\non-reward\NAc_agent_initiated"
)

# %% [markdown]
# ## determine sample size

# %%
def count_bouts_by_region_and_initiator(experiment):

    rows = []

    for trial_name, trial in experiment.trials.items():

        # skip invalid trials
        if trial.behaviors is None or trial.behaviors.empty:
            continue

        df = trial.behaviors

        # infer region per file ONLY as fallback
        # (DO NOT rely on this for per-event truth)
        if isinstance(trial.subject_name, str) and "_" in trial.subject_name:
            parts = trial.subject_name.split("_")
        else:
            parts = [trial.subject_name]

        # SUBJECT-INITIATED BOUTS
        subj_df = df[
            (df["Bout"] == "subject_behavior") &
            (df["Initiators"] == "Subject")
        ]

        if not subj_df.empty:
            rows.append({
                "region_file": parts[0][0],   # fallback only
                "initiator": "Subject",
                "count": len(subj_df)
            })

        # AGENT-INITIATED BOUTS
        agent_df = df[
            (df["Bout"] == "agent_behavior") &
            (df["Initiators"] == "Social Agent")
        ]

        if not agent_df.empty:
            rows.append({
                "region_file": parts[0][0],   # fallback only
                "initiator": "Social Agent",
                "count": len(agent_df)
            })


    df_counts = pd.DataFrame(rows)

    if df_counts.empty:
        return df_counts, df_counts, df_counts

    summary = (
        df_counts
        .groupby(["region_file", "initiator"])["count"]
        .sum()
        .reset_index()
    )

    pivot = summary.pivot(
        index="region_file",
        columns="initiator",
        values="count"
    ).fillna(0)

    return df_counts, summary, pivot

# %%
df_counts, summary, pivot = count_bouts_by_region_and_initiator(experiment)

print(summary)
print(pivot)
# Out:
#   region_file     initiator  count
# 0           n  Social Agent    449
# 1           n       Subject    482
# 2           p  Social Agent    361
# 3           p       Subject    337
# initiator    Social Agent  Subject
# region_file
# n                     449      482
# p                     361      337
