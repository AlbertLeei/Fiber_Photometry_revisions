# %%
import os
import sys

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(PROJECT_ROOT)

from trial_class import *
from experiment_class import Experiment
from bouts_extension import *

# %%
# NAc: #15616F
# mPFC: #FFAF00

nac_experiment_path = r"C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined_Cohorts\Hab_Dishab\All\nac"
nac_csv_base_path = r"C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined_Cohorts\Hab_Dishab\All\nac_csvs"
nac_color = '#15616F'

mpfc_experiment_path = r"C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined_Cohorts\Hab_Dishab\All\mpfc"
mpfc_csv_base_path = r"C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined_Cohorts\Hab_Dishab\All\mpfc_csvs"
mpfc_color = '#FFAF00'


experiment_path = r"C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined_Cohorts\Hab_Dishab\All\mpfc"
csv_base_path = r"C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined_Cohorts\Hab_Dishab\All\mpfc_csvs"
brain_region = '#FFAF00'

# experiment_path = "/Users/naylajimenez/Downloads/papers/dopamine/cohort-1-2/allcohorts/C1_2_3_Hab Dishab/all/nac"
# csv_base_path = "/Users/naylajimenez/Downloads/papers/dopamine/cohort-1-2/allcohorts/C1_2_3_Hab Dishab/all_csvs/nac_csvs"
# brain_region = '#15616F'

# experiment_path = "/Users/naylajimenez/Downloads/papers/dopamine/cohort-1-2/allcohorts/C1_2_3_Hab Dishab/all/mpfc"
# csv_base_path = "/Users/naylajimenez/Downloads/papers/dopamine/cohort-1-2/allcohorts/C1_2_3_Hab Dishab/all_csvs/mpfc_csvs"
# brain_region = '#FFAF00'

save_images = False

# %%
# groups csv + experiment data into one variable
n_experiment = Experiment(nac_experiment_path, nac_csv_base_path)
p_experiment = Experiment(mpfc_experiment_path, mpfc_csv_base_path)


# batch process the data, removing the specified time segments for subjects
n_experiment.default_batch_process()
p_experiment.default_batch_process()
# Out:
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined_Cohorts\Hab_Dishab\All\nac\n6-240821-100116\Notes.txt
# read from t=0s to t=1335.06s
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined_Cohorts\Hab_Dishab\All\nac\n7-240821-114717\Notes.txt
# read from t=0s to t=1309.86s
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined_Cohorts\Hab_Dishab\All\nac\nn1-250115-052028\Notes.txt
# read from t=0s to t=1351.05s
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined_Cohorts\Hab_Dishab\All\nac\nn2-250115-054951\Notes.txt
# read from t=0s to t=1349.96s
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined_Cohorts\Hab_Dishab\All\nac\nn3-250115-064154\Notes.txt
# read from t=0s to t=1377.67s
# ...

# %%
bout_definitions = [
    {'prefix': 's1', 'introduced': 's1_Introduced', 'removed': 's1_Removed'},
    {'prefix': 's2', 'introduced': 's2_Introduced', 'removed': 's2_Removed'}
]

n_experiment.group_extract_manual_annotations(bout_definitions, first_only=False)
p_experiment.group_extract_manual_annotations(bout_definitions, first_only=False)
# Out:
# Processing behaviors for n6-240821-100116...
# Processing behaviors for n7-240821-114717...
# Processing behaviors for nn1-250115-052028...
# Processing behaviors for nn2-250115-054951...
# Processing behaviors for nn3-250115-064154...
# Processing behaviors for nn4-250115-072812...
# Processing behaviors for nn5-250114-083827...
# Processing behaviors for nn6-250114-093117...
# Processing behaviors for nn7-250114-100133...
# Processing behaviors for nn8-250114-103839...
# Processing behaviors for p1-240516-064158...
# Processing behaviors for p2-240516-071921...
# Processing behaviors for p3-240516-075659...
# Processing behaviors for p5-240821-092649...
# Processing behaviors for p6-240821-103616...
# Processing behaviors for p7-240821-111323...
# Processing behaviors for p8-240821-121933...
# Processing behaviors for pp1-250115-080205...
# Processing behaviors for pp2-250115-083739...
# Processing behaviors for pp3-250115-091306...
# Processing behaviors for pp4-250115-094555...
# ...

# %% [markdown]
# # Total Investigation Time & Average Bout Duration

# %% [markdown]
# Functions from hd_extension:<br>
# get_trial_dataframes(experiment)<br>
# create_metadata_dataframe(exp_dict, behavior="Investigation")

# %%
n_exp_dict = get_trial_dataframes(n_experiment)
p_exp_dict = get_trial_dataframes(p_experiment)

# %%
desired_bouts = ['s1-1', 's1-2', 's1-3', 's1-4', 's1-5', 's2-1']
n_metadata_df = create_metadata_dataframe(n_exp_dict, behavior="Investigation", desired_bouts=desired_bouts)
p_metadata_df = create_metadata_dataframe(p_exp_dict, behavior="Investigation", desired_bouts=desired_bouts)

# %%
# Total Investigation Time Across Bouts
plot_behavior_across_bouts_no_identities(
    metadata_df=p_metadata_df,
    y_col="Total Investigation Time",
    behavior="Investigation",
    title=" ",
    xlabel="Intruder",
    ylabel="Total Investigation Time (s)",
    custom_xtick_labels=["i1", "i1", "i1", "i1", "i1", "i2"],
    custom_xtick_colors=["blue", "blue", "blue", "blue", "blue", "#E06928"],
    ylim=(0, 120),
    bar_color='#2093FF47',
    yticks_increment=20,
    figsize=(12,7),
    pad_inches=0.2,
    save=True,
    save_name=r"Hab_Dishab_Plots\Timing_Plots\mPFC_Total_Investigation_Time_Across_Bouts_noN5.png"
)
# Out:
# Paired t-test results:
#   comparison  n  t_stat  p_value  cohen_d
# s1-1 vs s1-2 15  6.0790   0.0000   1.5696
# s1-1 vs s1-3 15  5.4553   0.0001   1.4086
# s1-1 vs s1-4 15  5.0173   0.0002   1.2955
# s1-1 vs s1-5 15  4.8686   0.0002   1.2571
# s1-1 vs s2-1 15  2.2600   0.0403   0.5835
# s1-2 vs s1-3 15  1.0951   0.2920   0.2828
# s1-2 vs s1-4 15  1.6586   0.1194   0.4283
# s1-2 vs s1-5 15  1.2559   0.2297   0.3243
# s1-2 vs s2-1 15 -3.1089   0.0077  -0.8027
# s1-3 vs s1-4 15  1.1978   0.2509   0.3093
# s1-3 vs s1-5 15  0.4252   0.6771   0.1098
# s1-3 vs s2-1 15 -4.2704   0.0008  -1.1026
# s1-4 vs s1-5 15 -1.5759   0.1374  -0.4069
# s1-4 vs s2-1 15 -4.0841   0.0011  -1.0545
# s1-5 vs s2-1 15 -3.9161   0.0016  -1.0111
# (Bout        s1-1    s1-2    s1-3    s1-4    s1-5    s2-1
#  Subject
#  p1        53.065  12.266  54.333  27.400  23.067  53.999
#  p2        61.665  39.401  18.800  15.935  11.931  46.664
#  p3        11.267   3.333   6.267  25.401  18.733  24.998
# ...

# %%
# Total Investigation Time Across Bouts
plot_behavior_across_bouts_no_identities(
    metadata_df=n_metadata_df,
    y_col="Total Investigation Time",
    behavior="Investigation",
    title=" ",
    xlabel="Intruder",
    ylabel="Total Investigation Time (s)",
    custom_xtick_labels=["i1", "i1", "i1", "i1", "i1", "i2"],
    custom_xtick_colors=["blue", "blue", "blue", "blue", "blue", "#E06928"],
    ylim=(0, 62),
    bar_color='#2093FF47',
    yticks_increment=10,
    figsize=(12,7),
    pad_inches=0.5
    ,
    save=True,
    save_name=r"Hab_Dishab_Plots\Timing_Plots\NAc_Total_Investigation_Time_Across_Bouts_noN5.png"
)
# Out:
# Paired t-test results:
#   comparison  n  t_stat  p_value  cohen_d
# s1-1 vs s1-2 10  2.9609   0.0159   0.9363
# s1-1 vs s1-3 10  3.0117   0.0147   0.9524
# s1-1 vs s1-4 10  3.4258   0.0076   1.0833
# s1-1 vs s1-5 10  2.7553   0.0223   0.8713
# s1-1 vs s2-1 10 -1.6813   0.1270  -0.5317
# s1-2 vs s1-3 10  2.3514   0.0432   0.7436
# s1-2 vs s1-4 10  1.9328   0.0853   0.6112
# s1-2 vs s1-5 10  0.7836   0.4534   0.2478
# s1-2 vs s2-1 10 -3.6671   0.0052  -1.1596
# s1-3 vs s1-4 10 -0.7124   0.4943  -0.2253
# s1-3 vs s1-5 10 -2.3687   0.0420  -0.7490
# s1-3 vs s2-1 10 -4.3860   0.0018  -1.3870
# s1-4 vs s1-5 10 -1.2809   0.2323  -0.4050
# s1-4 vs s2-1 10 -4.4108   0.0017  -1.3948
# s1-5 vs s2-1 10 -4.5765   0.0013  -1.4472
# (Bout     s1-1  s1-2  s1-3  s1-4  s1-5  s2-1
#  Subject
#  n6        7.9  11.3   4.0   2.3   6.2  18.8
#  n7       15.6   8.7   4.2   0.5   1.2   1.9
#  nn1      10.6   5.2   9.8   2.7  12.6  62.1
#  nn2      36.2  10.5   3.2  16.8  14.7  50.4
# ...

# %% [markdown]
# Outlier test - MAD

# %%
import numpy as np

# --- MAD helper ---
def mad_flags(series, threshold=3.5):
    med = series.median()
    mad = np.median(np.abs(series - med))
    if mad == 0:
        return pd.Series(False, index=series.index)  # avoid div-by-zero
    mz = 0.6745 * (series - med) / mad
    return mz.abs() > threshold

# --- compute flags (aligned to full index) ---
flags = pd.DataFrame({
    "Total Time Outlier": mad_flags(metadata_df["Total Investigation Time"]),
    "Avg Duration Outlier": mad_flags(metadata_df["Average Bout Duration"])
}, index=metadata_df.index)

# --- attach to original df ---
labeled = metadata_df.join(flags)

# --- rows that are outliers in either metric ---
outlier_rows = labeled[labeled["Total Time Outlier"] | labeled["Avg Duration Outlier"]][
    ["Subject", "Bout", "Total Time Outlier", "Avg Duration Outlier"]
]

# --- subjects with outliers (per metric and overall) ---
subjects_total_time = labeled.loc[labeled["Total Time Outlier"], "Subject"].unique().tolist()
subjects_avg_duration = labeled.loc[labeled["Avg Duration Outlier"], "Subject"].unique().tolist()
subjects_any = labeled.loc[
    labeled["Total Time Outlier"] | labeled["Avg Duration Outlier"], "Subject"
].unique().tolist()

# Inspect:
# labeled           # full table with flags
# outlier_rows      # only flagged rows
# subjects_total_time, subjects_avg_duration, subjects_any
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 14
#      10     return mz.abs() > threshold
#      12 # --- compute flags (aligned to full index) ---
#      13 flags = pd.DataFrame({
# ---> 14     "Total Time Outlier": mad_flags(metadata_df["Total Investigation Time"]),
#      15     "Avg Duration Outlier": mad_flags(metadata_df["Average Bout Duration"])
#      16 }, index=metadata_df.index)
#      18 # --- attach to original df ---
#      19 labeled = metadata_df.join(flags)
#
# NameError: name 'metadata_df' is not defined

# %%
outlier_rows
# Out:
#    Subject  Bout  Total Time Outlier  Avg Duration Outlier
# 54     pp3  s1-1                True                  True
# 59     pp3  s2-1                True                 False

# %%
# Total Investigation Time Across Bouts
plot_behavior_times_across_bouts_gray_bars_only(
    metadata_df=metadata_df,
    y_col="Total Investigation Time",
    behavior="Investigation",
    title=" ",
    xlabel="Intruder",
    ylabel="Total Investigation Time (s)",
    custom_xtick_labels=["i1", "i1", "i1", "i1", "i1", "i2"],
    custom_xtick_colors=["blue", "blue", "blue", "blue", "blue", "#E06928"],
    ylim=(0, 60),
    bar_color=brain_region,
    yticks_increment=20,
    figsize=(12,7),
    pad_inches=0.1,
    save=False,
    save_name=r"Hab_Dishab_Plots\Timing_Plots\mPFC_C123_Total_Investigation_Time_Across_Bouts_no_mice.png"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Total Investigation Time Across Bouts
# ----> 2 plot_behavior_times_across_bouts_gray_bars_only(
#       3     metadata_df=metadata_df,
#       4     y_col="Total Investigation Time",
#       5     behavior="Investigation",
#       6     title=" ",
#       7     xlabel="Intruder",
#       8     ylabel="Total Investigation Time (s)",
#       9     custom_xtick_labels=["i1", "i1", "i1", "i1", "i1", "i2"],
#      10     custom_xtick_colors=["blue", "blue", "blue", "blue", "blue", "#E06928"],
#      11     ylim=(0, 60),
#      12     bar_color=brain_region,
#      13     yticks_increment=20,
#      14     figsize=(12,7),
#      15     pad_inches=0.1,
#      16     save=False,
#      17     save_name=r"Hab_Dishab_Plots\Timing_Plots\mPFC_C123_Total_Investigation_Time_Across_Bouts_no_mice.png"
#      18 )
# ...

# %%
# plot_behavior_times_across_bouts_colored(
#     metadata_df=metadata_df,
#     y_col="Total Investigation Time",
#     behavior="Investigation",
#     title="Investigation Time Across Bouts",
#     xlabel="Intruder",
#     ylabel="Total Investigation Time (s)",
#     custom_xtick_labels=["i1", "i1", "i1", "i1", "i1", "i2"],
#     custom_xtick_colors=["blue", "blue", "blue", "blue", "blue", "#E06928"],
#     ylim=(0, 60),
#     bar_color=brain_region,
#     yticks_increment=20,
#     figsize=(12,7),
#     pad_inches=0.1,
#     save=False,
#     save_name=r"Hab_Dishab_Plots\Timing_Plots\NAc_C1-C2_Total_Investigation_Time_Across_Bouts.png"
# )

# %%
# Average Bout Duration Across Bouts
plot_behavior_times_across_bouts_gray(
    metadata_df=metadata_df,
    y_col="Average Bout Duration",
    behavior="Investigation",
    title="Average Bout Duration Across Bouts",
    xlabel="Intruder",
    ylabel="Bout Duration (s)",
    custom_xtick_labels=["i1", "i1", "i1", "i1", "i1", "i2"],
    custom_xtick_colors=["blue", "blue", "blue", "blue", "blue", "#E06928"],
    ylim=(0, 15),
    bar_color=brain_region,
    yticks_increment=2,
    figsize=(12,7),
    pad_inches=0.1,
    save=False,
    save_name=r"Hab_Dishab_Plots\Timing_Plots\NAc_C3_Average_Bout_Duration_Across_Bouts.png"
)

# %%
# Average Bout Duration Across Bouts
plot_behavior_times_across_bouts_colored(
    metadata_df=metadata_df,
    y_col="Average Bout Duration",
    behavior="Investigation",
    title="Average Bout Duration Across Bouts",
    xlabel="Intruder",
    ylabel="Bout Duration (s)",
    custom_xtick_labels=["i1", "i1", "i1", "i1", "i1", "i2"],
    custom_xtick_colors=["blue", "blue", "blue", "blue", "blue", "#E06928"],
    ylim=(0, 15),
    bar_color=brain_region,
    yticks_increment=2,
    figsize=(12,7),
    pad_inches=0.1,
    save=False,
    save_name=r"Hab_Dishab_Plots\Timing_Plots\NAc_C3_Average_Bout_Duration_Across_Bouts.png"
)
